# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import cohen_kappa_score
from sklearn import metrics
from sklearn import tree
import pickle
import warnings

# %%
df = pd.read_csv("info.csv")

# %%
df.head()
# Out:
#    ID  lon_data  lat_data  temp_data  pressure_data  humidity_data  \
# 0   1   50.0245   26.5208     307.26           1003             14
# 1   2   50.0245   26.5208     304.26           1006             16
# 2   3   50.0245   26.5208     300.26           1006             28
# 3   4   50.0245   26.5208     303.26           1006             22
# 4   5   50.0245   26.5208     302.26           1008             29
#
#    cloud_data  visibility_data  wind_speed_data            date
# 0           0            10000             4.54  2022/05/31\r\n
# 1           0            10000             3.07  2022/06/01\r\n
# 2           0            10000             4.51  2022/06/02\r\n
# 3           0            10000             3.91  2022/06/03\r\n
# 4           0            10000             4.56  2022/06/04\r\n

# %%
df[['ID','lon_data','lat_data','temp_data','pressure_data','humidity_data','cloud_data','visibility_data','wind_speed_data']][:31]
# Out:
#     ID  lon_data  lat_data  temp_data  pressure_data  humidity_data  \
# 0    1   50.0245   26.5208     307.26           1003             14
# 1    2   50.0245   26.5208     304.26           1006             16
# 2    3   50.0245   26.5208     300.26           1006             28
# 3    4   50.0245   26.5208     303.26           1006             22
# 4    5   50.0245   26.5208     302.26           1008             29
# 5    6   50.0245   26.5208     302.62           1009             30
# 6    7   50.0245   26.5208     301.87           1007             33
# 7    8   50.0245   26.5208     302.60           1000             52
# 8    9   50.0245   26.5208     304.45           1002             23
# 9   10   50.0245   26.5208     304.51           1006             32
# 10  11   50.0245   26.5208     305.27           1005             36
# 11  12   50.0245   26.5208     303.65           1007             45
# 12  13   50.0245   26.5208     302.27           1007             49
# ...

# %%
df[['ID','lon_data','lat_data','temp_data','pressure_data','humidity_data','cloud_data','visibility_data','wind_speed_data']].head()
# Out:
#    ID  lon_data  lat_data  temp_data  pressure_data  humidity_data  \
# 0   1   50.0245   26.5208     307.26           1003             14
# 1   2   50.0245   26.5208     304.26           1006             16
# 2   3   50.0245   26.5208     300.26           1006             28
# 3   4   50.0245   26.5208     303.26           1006             22
# 4   5   50.0245   26.5208     302.26           1008             29
#
#    cloud_data  visibility_data  wind_speed_data
# 0           0            10000             4.54
# 1           0            10000             3.07
# 2           0            10000             4.51
# 3           0            10000             3.91
# 4           0            10000             4.56

# %%
for i in range(len(df)):
    df[['lon_data','lat_data','temp_data','pressure_data','humidity_data','cloud_data','visibility_data','wind_speed_data']][:i]

# %%
df[['lon_data','lat_data','temp_data','pressure_data','humidity_data','cloud_data','visibility_data','wind_speed_data']][:i]
# Out:
#     lon_data  lat_data  temp_data  pressure_data  humidity_data  cloud_data  \
# 0    50.0245   26.5208     307.26           1003             14           0
# 1    50.0245   26.5208     304.26           1006             16           0
# 2    50.0245   26.5208     300.26           1006             28           0
# 3    50.0245   26.5208     303.26           1006             22           0
# 4    50.0245   26.5208     302.26           1008             29           0
# 5    50.0245   26.5208     302.62           1009             30           0
# 6    50.0245   26.5208     301.87           1007             33           0
# 7    50.0245   26.5208     302.60           1000             52           0
# 8    50.0245   26.5208     304.45           1002             23           0
# 9    50.0245   26.5208     304.51           1006             32           0
# 10   50.0245   26.5208     305.27           1005             36           0
# ...

# %%
df[:1]
# Out:
#    ID  lon_data  lat_data  temp_data  pressure_data  humidity_data  \
# 0   1   50.0245   26.5208     307.26           1003             14
#
#    cloud_data  visibility_data  wind_speed_data            date
# 0           0            10000             4.54  2022/05/31\r\n

# %%
df[['lon_data','lat_data','temp_data','pressure_data','humidity_data','cloud_data','visibility_data','wind_speed_data']][:5]
# Out:
#    lon_data  lat_data  temp_data  pressure_data  humidity_data  cloud_data  \
# 0   50.0245   26.5208     307.26           1003             14           0
# 1   50.0245   26.5208     304.26           1006             16           0
# 2   50.0245   26.5208     300.26           1006             28           0
# 3   50.0245   26.5208     303.26           1006             22           0
# 4   50.0245   26.5208     302.26           1008             29           0
#
#    visibility_data  wind_speed_data
# 0            10000             4.54
# 1            10000             3.07
# 2            10000             4.51
# 3            10000             3.91
# 4            10000             4.56

# %%
convertedArr = df[['lon_data','lat_data','temp_data','pressure_data','humidity_data','cloud_data','visibility_data','wind_speed_data']][:20].values.tolist()

# %%
len(convertedArr)
# Out:
# 20
